# %%
import pandas as pd 
pd.set_option("display.max_columns", 30)

# %%
df = pd.read_csv('../data/Questionnaire.csv')

# %%
df.head()
# Out:
#           Timestamp  Age of Participant  Gender   Nationality  \
# 0  7/6/2020 1:23:29                  22    Male   Bangladeshi
# 1  7/6/2020 1:27:29                  21    Male  Bangladeshi
# 2  7/6/2020 2:49:03                  21  Female  Bangladeshi
# 3  7/6/2020 1:48:30                  21    Male  Bangladeshi
# 4  7/6/2020 2:12:32                  20  Female  Bangladeshi
#
#      Academic Status Field of Education                          Email  \
# 0               BS.c       Microbiology            linconjnu@gmail.com
# 1  Honours 2nd year       Microbiology   mdarafat01853467085@gmail.com
# 2                BSc      Microbiology      sadianasertanjin@gmail.com
# 3               B.sc      Microbiology   prantoiftakherahmed@gmail.com
# 4                BSc      Microbiology        miftah.aourthy@gmail.com
#
#   Contact Number (Optional)  \
# 0                1742100015
# 1                       NaN
# 2                       NaN
# 3                1957353494
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age of Participant', 'Gender', 'Nationality',
#        'Academic Status', 'Field of Education', 'Email',
#        'Contact Number (Optional)',
#        'Do you know about how antibiotics differ from other drugs?',
#        'Pick the most appropriate definition of antibiotics',
#        'How can you identify an antibiotic?',
#        'What is your idea about the importance of antibiotics?',
#        ' What is the most dangerous impact of antibiotics?',
#        'What is your opinion about antibiotic usage?',
#        'What is your perception of drug-resistant germs?',
#        'Do you have idea about antibiotic resistance as a threat to public health?',
#        'Choose a statement that you feel is the best strategy to face antibiotic-resistance',
#        'Which of the strategies have you heard about against antibiotic resistance?',
#        'What type of movement on public health issues do you think will be effective in setting malpractices right?',
# ...

# %%
df['Do you know about how antibiotics differ from other drugs?'] = df['Do you know about how antibiotics differ from other drugs?'].str.replace(r"\([^()]*\)","")
df['Pick the most appropriate definition of antibiotics'] = df['Pick the most appropriate definition of antibiotics'].str.replace(r"\([^()]*\)","")

# %%
df['How can you identify an antibiotic?'] = (df['How can you identify an antibiotic?']).str.replace(r"\([^()]*\)","")

# %%
df['What is your idea about the importance of antibiotics?'] = df['What is your idea about the importance of antibiotics?'].str.replace(r"\([^()]*\)","")

# %%
df['What is your opinion about antibiotic usage?'] = df['What is your opinion about antibiotic usage?'].str.replace(r"\([^()]*\)","")

# %%
df['What is your perception of drug-resistant germs?'] = df['What is your perception of drug-resistant germs?'].str.replace(r"\([^()]*\)","")

# %%
df['Do you have idea about antibiotic resistance as a threat to public health?'] = df['Do you have idea about antibiotic resistance as a threat to public health?'].str.replace(r"\([^()]*\)","")

# %%
df['Choose a statement that you feel is the best strategy to face antibiotic-resistance'] = df['Choose a statement that you feel is the best strategy to face antibiotic-resistance'].str.replace(r"\([^()]*\)","")

# %%
df['Which of the strategies have you heard about against antibiotic resistance?'] = df['Which of the strategies have you heard about against antibiotic resistance?'].str.replace(r"\([^()]*\)","")

# %%
df['What type of movement on public health issues do you think will be effective in setting malpractices right?'] = df['What type of movement on public health issues do you think will be effective in setting malpractices right?'].str.replace(r"\([^()]*\)","")

# %%
df['Why do you think public health issues don’t get due importance in public opinion?'] = df['Why do you think public health issues don’t get due importance in public opinion?'].str.replace(r"\([^()]*\)","")

# %%
df['How many antibiotics have you taken over the past 3 years?'] = df['How many antibiotics have you taken over the past 3 years?'].str.replace(r"\([^()]*\)","")

# %%
df['What was the pattern of antibiotic use?'] = df['What was the pattern of antibiotic use?'].str.replace(r"\([^()]*\)","")

# %%
df['What was the formulation of the product used?'] = df['What was the formulation of the product used?'].str.replace(r"\([^()]*\)","")

# %%
df['What was the best experience with the consumption of antibiotics?'] = df['What was the best experience with the consumption of antibiotics?'].str.replace(r"\([^()]*\)","")

# %%
df['What was the worst experience with the consumption of antibiotics?'] = df['What was the worst experience with the consumption of antibiotics?'].str.replace(r"\([^()]*\)","")

# %%
df['How did you come to consume the antibiotic?'] = df['How did you come to consume the antibiotic?'].str.replace(r"\([^()]*\)","")

# %%
df['Have you experienced treatment failure from antibiotic consumption?'] = df['Have you experienced treatment failure from antibiotic consumption?'].str.replace(r"\([^()]*\)","")

# %%
df['What was your understanding of treatment failure?'] = df['What was your understanding of treatment failure?'].str.replace(r"\([^()]*\)","")

# %%
df.to_csv("../data/cleaned_data.csv", index=False)

# %%
# https://stackoverflow.com/questions/20894525/how-to-remove-parentheses-and-all-data-within-using-pandas-python
